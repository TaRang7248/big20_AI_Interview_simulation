# %%
# GStreamer 설치 확인
import gi
gi.require_version('Gst', '1.0')
from gi.repository import Gst

Gst.init(None)
print("✅ GStreamer 버전:", Gst.version_string())
# Out:
# ✅ GStreamer 버전: GStreamer 1.28.0
