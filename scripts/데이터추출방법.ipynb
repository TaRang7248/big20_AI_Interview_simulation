# %%
# BeautifulSoup 4 (bs4)
# 1. requests 사용해서 테이터 수집 : 텍스트
# 2. 파싱 >> 파싱트리(DOM으로 되어있다나?) 생성 (selector)  << BeautifulSoup 

# 2.1 파싱 후 4개의 obj 생성 (Tag, BeautifulSoup, NavigableString, Comment -  각 방법,메소드마다 추출방법이 달라짐)
# - 1. Tag Object : html 문서의 태그
# - 2. BeautifulSoup object : 문서 전체, 최상위(<html>) 

# 3. selector(선택) >> 데이터추출
# 3.1 Tag, BeautifulSoup obj 공통 메소드
# _____tag selector(태그선택자): tag, id, class, attr ______
# - find(tag) : 단일 선택 >> Tag obj 반환
# - find_all(tag) : 다중(여러개) 선택 >> [Tag, Tag, ...]
# _____CSS selector(CSS선택자): tag선택자 포함, 상세한 선택_____
# - select(selector) : [Tag obj1, Tag obj2, ...]
# - select_one(selector) : 첫번째 Tag obj 

# 3.2 추가 메소드
# = find_parent() : 부모탐색
# - find_next_sibling() : 이후 형제탐색
# - find_previous_sibling() : 이전 형제탐색

# 3.3 Tag obj 속성,메소드
# ----속성
# .name : 태그 이름 반환
# .attrs : attribute 들을 딕셔너리 형태로 반환 >> {'href':'https://www...','target':'_blink}
# ['속성이름'] : tag['href'] >> 'https://www. ...' << 주의!! 키(속성명)가 없으면 Error 발생 
# ----메소드 
# .get( 속성명 ) : 없으면 None 반환 << 조금 더 쓰기 쉽겠죵
# .has_attr('속성명') : 속성이 존재 여부 (T/F)

# 3.4 텍스트(content) 관련 속성 메소드
# ----속성
# - 오브젝트.string : 텍스트 반환
# - 오브젝트.strings : 본인 + 하위태그들의 텍스트들까지 다 가져올 수 있음 (줄바꿈 공백 포함 주의)
# ----메소드
# - .get_text() : 해당 태그, 하위 태그 내의 텍스트 반환(줄바꿈 공백포함), 하나의 문자열로 반환

# 4. 데이터프레임 생성
